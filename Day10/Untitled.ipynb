# %%
import pandas as pd

# %%
df = pd.read_excel("movies-db-1.xlsx")
df
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...

# %%
df.describe()
# Out:
#          movie_id  release_year  imdb_rating  language_id
# count   39.000000     39.000000    38.000000    39.000000
# mean   120.666667   2006.282051     7.947368     3.435897
# std     11.795033     17.945750     1.180869     1.970772
# min    101.000000   1946.000000     1.900000     1.000000
# 25%    110.500000   2000.500000     7.825000     1.000000
# 50%    121.000000   2013.000000     8.100000     5.000000
# 75%    130.500000   2018.000000     8.400000     5.000000
# max    140.000000   2022.000000     9.300000     7.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      39 non-null     int64
#  1   title         39 non-null     object
#  2   industry      39 non-null     object
#  3   release_year  39 non-null     int64
#  4   imdb_rating   38 non-null     float64
#  5   studio        36 non-null     object
#  6   language_id   39 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.3+ KB

# %%
df.columns
# Out:
# Index(['movie_id', 'title', 'industry', 'release_year', 'imdb_rating',
#        'studio', 'language_id'],
#       dtype='object')

# %%
df.dtypes
# Out:
# movie_id          int64
# title            object
# industry         object
# release_year      int64
# imdb_rating     float64
# studio           object
# language_id       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# movie_id        0
# title           0
# industry        0
# release_year    0
# imdb_rating     1
# studio          3
# language_id     0
# dtype: int64

# %%
df['studio']
# Out:
# 0                 Hombale Films
# 1                Marvel Studios
# 2                Marvel Studios
# 3                Marvel Studios
# 4                Marvel Studios
# 5              United Producers
# 6                Yash Raj Films
# 7            Vinod Chopra Films
# 8            Dharma Productions
# 9                           NaN
# 10    Castle Rock Entertainment
# 11        Warner Bros. Pictures
# 12        Warner Bros. Pictures
# 13            Columbia Pictures
# 14         Universal Pictures
# 15           Paramount Pictures
# 16                Liberty Films
# 17             20th Century Fox
# 18           Paramount Pictures
# 19                      Syncopy
# 20           Universal Pictures
# 21           Universal Pictures
# 22                          NaN
# 23               Marvel Studios
# 24               Marvel Studios
# 25    Government of West Bengal
# 26                          NaN
# 27     Vinod Chopra Productions
# 28           Vinod Chopra Films
# ...

# %%
df[['studio', 'release_year']]
# Out:
#                        studio  release_year
# 0               Hombale Films          2022
# 1              Marvel Studios          2022
# 2              Marvel Studios          2013
# 3              Marvel Studios          2017
# 4              Marvel Studios          2022
# 5            United Producers          1975
# 6              Yash Raj Films          1995
# 7          Vinod Chopra Films          2009
# 8          Dharma Productions          2001
# 9                         NaN          2015
# 10  Castle Rock Entertainment          1994
# 11      Warner Bros. Pictures          2010
# 12      Warner Bros. Pictures          2014
# 13          Columbia Pictures          2006
# 14       Universal Pictures            2000
# 15         Paramount Pictures          1997
# 16              Liberty Films          1946
# 17           20th Century Fox          2009
# 18         Paramount Pictures          1972
# 19                    Syncopy          2008
# ...

# %%
df.iloc[0:4]
# Out:
#    movie_id                                        title   industry  \
# 0       101                             K.G.F: Chapter 2  Bollywood
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       103                        Thor: The Dark World   Hollywood
# 3       104                              Thor: Ragnarok   Hollywood
#
#    release_year  imdb_rating          studio  language_id
# 0          2022          8.4   Hombale Films            3
# 1          2022          7.0  Marvel Studios            5
# 2          2013          6.8  Marvel Studios            5
# 3          2017          7.9  Marvel Studios            5

# %%
df['new_column'] = df['release_year'] + df['language_id']

# %%
df.drop(['new_column'],axis=1, inplace=True)

# %%
df.rename(columns={'release_year':'releasing_year'})
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...

# %%
df.groupby(['title', 'imdb_rating']).size()
# Out:
# title                                        imdb_rating
# 3 Idiots                                     8.4            1
# Avatar                                       7.8            1
# Avengers: Endgame                            8.4            1
# Avengers: Infinity War                       8.4            1
# Baahubali: The Beginning                     8.0            1
# Bajirao Mastani                              7.2            1
# Bajrangi Bhaijaan                            8.1            1
# Captain America: The First Avenger           6.9            1
# Captain America: The Winter Soldier          7.8            1
# Dilwale Dulhania Le Jayenge                  8.0            1
# Doctor Strange in the Multiverse of Madness  7.0            1
# Gladiator                                    8.5            1
# Inception                                    8.8            1
# Interstellar                                 8.6            1
# ...

# %%
df.sort_values(['movie_id'],ascending=True)
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...

# %%
df['studio'].fillna('value')
# Out:
# 0                 Hombale Films
# 1                Marvel Studios
# 2                Marvel Studios
# 3                Marvel Studios
# 4                Marvel Studios
# 5              United Producers
# 6                Yash Raj Films
# 7            Vinod Chopra Films
# 8            Dharma Productions
# 9                         value
# 10    Castle Rock Entertainment
# 11        Warner Bros. Pictures
# 12        Warner Bros. Pictures
# 13            Columbia Pictures
# 14         Universal Pictures
# 15           Paramount Pictures
# 16                Liberty Films
# 17             20th Century Fox
# 18           Paramount Pictures
# 19                      Syncopy
# 20           Universal Pictures
# 21           Universal Pictures
# 22                        value
# 23               Marvel Studios
# 24               Marvel Studios
# 25    Government of West Bengal
# 26                        value
# 27     Vinod Chopra Productions
# 28           Vinod Chopra Films
# ...

# %%
df.dropna()
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# 13       115                     The Pursuit of Happyness  Hollywood
# ...

# %%
df1 = df[['movie_id','title']]
df1.head()
# Out:
#    movie_id                                        title
# 0       101                             K.G.F: Chapter 2
# 1       102  Doctor Strange in the Multiverse of Madness
# 2       103                        Thor: The Dark World
# 3       104                              Thor: Ragnarok
# 4       105                      Thor: Love and Thunder

# %%
df2 = df[['movie_id', 'imdb_rating']]
df2.head()
# Out:
#    movie_id  imdb_rating
# 0       101          8.4
# 1       102          7.0
# 2       103          6.8
# 3       104          7.9
# 4       105          6.8

# %%
df3 = pd.merge(df1, df2 , on='movie_id')
df3.head()
# Out:
#    movie_id                                        title  imdb_rating
# 0       101                             K.G.F: Chapter 2          8.4
# 1       102  Doctor Strange in the Multiverse of Madness          7.0
# 2       103                        Thor: The Dark World           6.8
# 3       104                              Thor: Ragnarok           7.9
# 4       105                      Thor: Love and Thunder           6.8
